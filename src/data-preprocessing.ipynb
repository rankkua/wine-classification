# %% [markdown]
# ## Exploratory Data Analysis with Data Preprocessing
#
# 1. load data
# 2. print basic info, nullcount, cols, dtypes
# 3. visualize correlations etc
# 4. check class balance
# 5. handle missing values

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 

sns.set_style('whitegrid')

cols = [
    'class',
    'Alcohol',
    'Malic acid',
    'Ash',
    'Alcalinity of ash',
    'Magnesium',
    'Total phenols',
    'Flavanoids',
    'Nonflavanoid phenols',
    'Proanthocyanins',
    'Color intensity',
    'Hue',
    'OD280/OD315 of diluted wines',
    'Proline'
]

df = pd.read_csv('../data/raw/wine.data', names=cols, delimiter=',', header=None)

df.sample(4)
# Out:
#      class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 127      2    11.79        2.13  2.78               28.5         92
# 43       1    13.24        3.98  2.29               17.5        103
# 82       2    12.08        1.13  2.51               24.0         78
# 159      3    13.48        1.67  2.64               22.5         89
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 127           2.13        2.24                  0.58             1.76
# 43            2.64        2.63                  0.32             1.66
# 82            2.00        1.58                  0.40             1.40
# 159           2.60        1.10                  0.52             2.29
#
#      Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 127             3.00  0.97                          2.44      466
# 43              4.36  0.82                          3.00      680
# 82              2.20  1.31                          2.72      630
# ...

# %% [markdown]
# Print basic information about the data

# %%
df.info()
df.isnull().sum()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   class                         178 non-null    int64
#  1   Alcohol                       178 non-null    float64
#  2   Malic acid                    178 non-null    float64
#  3   Ash                           178 non-null    float64
#  4   Alcalinity of ash             178 non-null    float64
#  5   Magnesium                     178 non-null    int64
#  6   Total phenols                 178 non-null    float64
#  7   Flavanoids                    178 non-null    float64
#  8   Nonflavanoid phenols          178 non-null    float64
#  9   Proanthocyanins               178 non-null    float64
#  10  Color intensity               178 non-null    float64
#  11  Hue                           178 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline'],
#       dtype='object')

# %%
df.describe().round(3)
# Out:
#          class  Alcohol  Malic acid      Ash  Alcalinity of ash  Magnesium  \
# count  178.000  178.000     178.000  178.000            178.000    178.000
# mean     1.938   13.001       2.336    2.367             19.495     99.742
# std      0.775    0.812       1.117    0.274              3.340     14.282
# min      1.000   11.030       0.740    1.360             10.600     70.000
# 25%      1.000   12.362       1.602    2.210             17.200     88.000
# 50%      2.000   13.050       1.865    2.360             19.500     98.000
# 75%      3.000   13.678       3.082    2.558             21.500    107.000
# max      3.000   14.830       5.800    3.230             30.000    162.000
#
#        Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# count        178.000     178.000               178.000          178.000
# mean           2.295       2.029                 0.362            1.591
# std            0.626       0.999                 0.124            0.572
# ...

# %%
data_balancec = df['class'].value_counts()
data_balancec
# Out:
# class
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.drop('class', axis=1).corr(), annot=True, fmt=".2f", cmap="cubehelix")
plt.title("Wine Data Feature Correlation Heatmap")
plt.show()

# outliers

# %% [markdown]
# **Data has 178 rows and 14 columns**
# **All datatypes are numbers**
# **None of the columns have missing values**
#
# **Class 1 has 59 wines**
# **Class 2 has 71 wines**
# **Class 3 has 48 wines**
#
# **Class is the classification target**
# **Other columns are features**

# %%
df['class'].value_counts()
# visualize data by class and features
# Out:
# class
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64
